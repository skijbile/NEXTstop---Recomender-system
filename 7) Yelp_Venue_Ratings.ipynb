# %% [markdown]
# ##### In this notebook we load the json file from yelp API with the reviews and ratings information and the Business_info.csv containing id and name
# ##### The json is parsed to create a new df with all the information :
#             venue
#             venue_id
#             reviews
#             ratings

# %%
import pandas as pd
import json

# %%
with open('ratings_yelp1.json','r') as f:
    ratings_yelp1=json.load(f)

# %%
Business_df=pd.read_csv('Business_info.csv')
Business_df
# Out:
#                 business_id              business_name         city
# 0             Not available        Farm League Brewing    Cambridge
# 1    SWITg8J1mXRPNFVwHZZwng                Dickens Pub      Calgary
# 2    j4bLjaBNI9yKRLtMtTmExQ                 El Mocambo      Toronto
# 3    HjZCuRTUCdykLkdgfU3R4A              Grand Bizarre      Toronto
# 4    0HUMwGGWabIdOAkdMqE3VQ              Starlite Room     Edmonton
# ..                      ...                        ...          ...
# 265           Not available             Northern Range       Verner
# 266  N8VUNmNoGqDLQ3c0O4yWuA   Royal Montreal Golf Club   Ile Bizard
# 267           Not available       Ancaster Fairgrounds  Jerseyville
# 268           Not available  Atlantic Canada Venue TBD      Halifax
# 269  79kZMIuEIDEGvhkHAjnNLQ             Sleeman Centre       Guelph
#
# [270 rows x 3 columns]

# %%
"""
columns required from the json
reviews-text, rating
"""
# Out:
# '\ncolumns required from the json\nreviews-text, rating\n'

# %%
ratings_yelp1[1]['reviews']#[0]['id'] #see the format of json
# Out:
# [{'id': 'RSfSIdt0dqAMOCGBxLHJfQ',
#   'url': 'https://www.yelp.com/biz/el-mocambo-toronto?adjust_creative=4zMbJMTsk-7dm2DLTujCKw&hrid=RSfSIdt0dqAMOCGBxLHJfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=4zMbJMTsk-7dm2DLTujCKw',
#   'text': 'El mocambo? More like hell no nah bro. The "Elmo" (as we called it back in the days when you millennials were tickling Sesame Street merch) was the place to...',
#   'rating': 2,
#   'time_created': '2023-12-01 17:44:42',
#   'user': {'id': 'sdUc23Aeh7x-C2nePy1YJA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=sdUc23Aeh7x-C2nePy1YJA',
#    'image_url': None,
#    'name': 'Joey L.'}},
#  {'id': 'uOJE0xzev7SyNaHItHbIyw',
#   'url': 'https://www.yelp.com/biz/el-mocambo-toronto?adjust_creative=4zMbJMTsk-7dm2DLTujCKw&hrid=uOJE0xzev7SyNaHItHbIyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=4zMbJMTsk-7dm2DLTujCKw',
#   'text': "Back in the year of our lord 1996 it was a badge of honour to be tossed out fo the El Mo was having one too many Labatt Blue's. But you'd have to be born...",
#   'rating': 1,
#   'time_created': '2023-12-01 17:49:47',
#   'user': {'id': 'f8ledJiG59D2Y5V5azxshA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=f8ledJiG59D2Y5V5azxshA',
#    'image_url': None,
#    'name': 'Johnny J.'}},
#  {'id': '99sLPaH5HtYLsiFmg3ZSpg',
#   'url': 'https://www.yelp.com/biz/el-mocambo-toronto?adjust_creative=4zMbJMTsk-7dm2DLTujCKw&hrid=99sLPaH5HtYLsiFmg3ZSpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=4zMbJMTsk-7dm2DLTujCKw',
#   'text': 'An icon in the city\nWe almost lost it recently\nTough times for concerts compared to the glory days\nI saw Mike Myers here in early 90s, he was alone and...',
#   'rating': 5,
#   'time_created': '2021-05-31 23:04:43',
#   'user': {'id': 'ic-tyi1jElL_umxZVh8KNA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=ic-tyi1jElL_umxZVh8KNA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/xKEO7RvtUlGiHxR9BiVmFg/o.jpg',
#    'name': 'Owen R.'}}]

# %%
review=[]
ratings=[]
venue_name=[]
venue_id=[]
city=[]
for index, row in Business_df.iterrows():
    # Get the business ID from the current row
    if row['business_id'] != 'Not available':
    
    # Search for the corresponding rating in the ratings JSON data
        for review_item in ratings_yelp1:
    
            if 'reviews' in review_item :
                
                 for item in review_item['reviews']:
                     

                    if 'text' in item:
                        review.append(item['text'])
                    else:
                        review.append('N/A')

                    if 'rating' in item:
                        ratings.append(item['rating'])
                    else:
                        ratings.append('N/A')
                
                    venue_name.append(row.iloc[1])
                    venue_id.append(row.iloc[0])
                    city.append(row.iloc[2])
            # else:
            #     review.append('Not available')
            #     ratings.append('Not available')
            #     venue_name.append(row.iloc[1])
            #     venue_id.append(row.iloc[0])
            #     city.append(row.iloc[2])
    else:
            review.append('N/A')
            ratings.append('N/A')
            venue_name.append(row.iloc[1])
            venue_id.append(row.iloc[0])
            city.append(row.iloc[2])

df=pd.DataFrame({'venue':venue_name,
                 'venue_id':venue_id,
                 'city':city,
                 'reviews':review,
                 'ratings':ratings})
df
# Out:
#                      venue                venue_id       city  \
# 0      Farm League Brewing           Not available  Cambridge
# 1              Dickens Pub  SWITg8J1mXRPNFVwHZZwng    Calgary
# 2              Dickens Pub  SWITg8J1mXRPNFVwHZZwng    Calgary
# 3              Dickens Pub  SWITg8J1mXRPNFVwHZZwng    Calgary
# 4              Dickens Pub  SWITg8J1mXRPNFVwHZZwng    Calgary
# ...                    ...                     ...        ...
# 17065       Sleeman Centre  79kZMIuEIDEGvhkHAjnNLQ     Guelph
# 17066       Sleeman Centre  79kZMIuEIDEGvhkHAjnNLQ     Guelph
# 17067       Sleeman Centre  79kZMIuEIDEGvhkHAjnNLQ     Guelph
# 17068       Sleeman Centre  79kZMIuEIDEGvhkHAjnNLQ     Guelph
# 17069       Sleeman Centre  79kZMIuEIDEGvhkHAjnNLQ     Guelph
#
#                                                  reviews ratings
# 0                                                    N/A     N/A
# 1      Good food, great service. The wing night is a ...       5
# 2      It's a cheap club with high prices. Expensive ...       1
# 3      Food was good and enjoyed are time while havin...       4
# 4      El mocambo? More like hell no nah bro. The "El...       2
# ...                                                  ...     ...
# 17065  Loved this place! My cousin had his wedding he...       4
# 17066  When my niece advised us she was getting marri...       4
# 17067  I had my wedding and got married here on May 1...       3
# 17068  I visited the Royal Montreal Golf Club for a t...       1
# 17069  This review is on the restaurant that oversees...       1
#
# [17070 rows x 5 columns]

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (15821, 5)

# %%
df.to_csv('Venue_Ratings.csv',index=False)
