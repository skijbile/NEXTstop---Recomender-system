# %%
import pandas as pd

# %%
#import the csv's
music_df=pd.read_csv('TicketMaster_music.csv')
sports_df=pd.read_csv('TicketMaster_sports.csv')

# %%
# Combine the 2 csv's vertically stacking them 

TicketMaster_df=pd.concat([music_df,sports_df],axis=0)

# %%
TicketMaster_df.head()
# Out:
#                           Event_name        Event_type Event_dates  \
# 0         P!NK: Summer Carnival 2024              Rock  2024-08-14
# 1         P!NK: Summer Carnival 2024              Rock  2024-08-31
# 2                     P!NK Live 2024              Rock  2024-09-06
# 3                     P!NK Live 2024              Rock  2024-09-07
# 4  Playhouse Presents: Billy Gillies  Dance/Electronic  2024-03-23
#
#   Event_start_times    Event_time_zone    Purchase_end_dates  \
# 0          18:30:00   America/New_York  2024-08-15T01:00:00Z
# 1          18:30:00     America/Denver  2024-09-01T02:30:00Z
# 2          19:30:00  America/Vancouver  2024-09-07T04:30:00Z
# 3          19:30:00  America/Vancouver  2024-09-08T04:30:00Z
# 4          22:00:00  America/Vancouver  2024-03-24T05:00:00Z
#
#                                          Venues       City            States  \
# 0                                 Rogers Centre    Toronto           Ontario
# 1  Commonwealth Stadium / Stade du Commonwealth   Edmonton           Alberta
# 2                                  Rogers Arena  Vancouver  British Columbia
# 3                                  Rogers Arena  Vancouver  British Columbia
# 4                                   Celebrities  Vancouver  British Columbia
#
#     Latitude   Longitude                                    Additional_info  \
# 0  43.641738  -79.391745  In the best interest of fans and staff, the Ev...
# 1  53.559219 -113.473569                      No additional notes available
# 2  49.277661 -123.108107  Originally scheduled for October 20th 2023. Pr...
# 3  49.277661 -123.108107  Originally scheduled for October 21st 2023. Pr...
# 4  49.279672 -123.130293                      No additional notes available
#
#                                        Ticket_limits  Age_restrictions  \
# 0  There is an overall 8 ticket limit for this ev...             False
# 1  There is an overall 8 ticket limit for this ev...             False
# 2  There is an overall 8 ticket limit for this ev...             False
# 3  There is an overall 8 ticket limit for this ev...             False
# 4              No ticket limit information available             False
#
#                                              Parking  \
# 0  There are several independently owned parking ...
# 1  Limited parking. LRT and special event Park an...
# 2  Underground parking (800 Griffiths Way) is ava...
# 3  Underground parking (800 Griffiths Way) is ava...
# 4                  Parking information not available
#
#                                         Accesibility
# 0  Accessible seats are subject to the same onsal...
# 1  Commonwealth Stadium is fully wheelchair acces...
# 2  Accessible platform seating is available on va...
# 3  Accessible platform seating is available on va...
# 4            Accessibility information not available

# %%
# save this to a csv
TicketMaster_df.to_csv("TicketMaster_merged.csv",index=False)

# %%
TicketMaster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179000 entries, 0 to 779
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Event_name          179000 non-null  object
#  1   Event_type          179000 non-null  object
#  2   Event_dates         179000 non-null  object
#  3   Event_start_times   179000 non-null  object
#  4   Event_time_zone     179000 non-null  object
#  5   Purchase_end_dates  179000 non-null  object
#  6   Venues              179000 non-null  object
#  7   City                179000 non-null  object
#  8   States              179000 non-null  object
#  9   Latitude            179000 non-null  float64
#  10  Longitude           179000 non-null  float64
#  11  Additional_info     179000 non-null  object
#  12  Ticket_limits       179000 non-null  object
#  13  Age_restrictions    179000 non-null  bool
#  14  Parking             179000 non-null  object
#  15  Accesibility        179000 non-null  object
# dtypes: bool(1), float64(2), object(13)
# memory usage: 22.0+ MB

# %%
latitude_array=TicketMaster_df['Latitude'].unique()
longitude_array=TicketMaster_df['Longitude'].unique()

# %%
Lat_Lon_df=pd.DataFrame({'latitude': latitude_array,
                         'longitude':longitude_array
                        })
Lat_Lon_df
# Out:
#      latitude   longitude
# 0   43.641738  -79.391745
# 1   53.559219 -113.473569
# 2   49.277661 -123.108107
# 3   49.279672 -123.130293
# 4   51.045633 -114.067099
# 5   43.647717  -79.401482
# 6   44.638320  -63.566012
# 7   49.280520 -123.100738
# 8   44.093832  -79.439523
# 9   45.451756  -75.650013
# 10  51.065100 -113.999110
# 11  53.590367 -113.433139
# 12  43.652919  -79.379452
# 13  49.279502 -123.129992
# 14  45.445444  -73.438116
# 15  46.813254  -71.214215
# 16  43.643925  -79.378323
# 17  45.296520  -75.927196
# 18  53.546911 -113.497237
# 19  51.038563 -114.052488
# 20  45.496129  -73.570472
